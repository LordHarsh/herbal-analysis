# %%
import pandas as pd
import os
import numpy
from mlxtend.frequent_patterns import association_rules
from FIM import apriori, fpgrowth, eclat, hmine
from FIM import association_rules
from FIM.utils import TransactionEncoder

# %%
# Preprocessing
data = pd.read_csv(r'../initial-data/Herbals and preperations.csv', encoding='latin-1')
data = data.apply(lambda x: x.str.lower() if x.dtype == "object" else x)
data=data.dropna(subset=['bot_name'])
data['bot_name'] = data['bot_name'].str.strip()

data['author'] = data['author'].dropna(axis=0).str.strip()
data = data.apply(lambda x: x.str.lower() if x.dtype == "object" else x)
data=data.dropna(subset=['bot_name'])
data['bot_name'] = data['bot_name'].str.strip()
columns_to_remove = ['herb_part', 'taste', 'potency', 'ultimate_taste', 'inherent_action']
data = data.drop(columns=columns_to_remove)

data.loc[data.bot_name.isin(['terminalia chebula', 'terminalia bellarica', 'phyllanthus emblica']), 'bot_name'] = 'triphala'
data.loc[data.bot_name.isin(['piper nigrum', 'piper longum', 'zingiber officinale']), 'bot_name'] = 'trikatu'
data.loc[(data.disease_category == 'diabetes') & (data.bot_name == 'saccharum officinarum'), 'bot_name'] = 'tinospora cordifolia'

# %%
# Convert all unique values in bot_name to a new series to be used as id
bot_name = data['bot_name'].unique()
bot_name = pd.Series(bot_name)
bot_name = bot_name.reset_index()
bot_name.columns = ['id', 'bot_name']
bot_name['id'] = bot_name['id'] + 1
if not os.path.exists(f'./split-data'):
    os.makedirs(f'./split-data')
bot_name.to_csv(r'./split-data/ids.csv', index=False)

# %%
# Splitting

data_dia = data.loc[data['disease_category'].apply(lambda x: x in ['diab/ tb ', 'diabetes'])].copy()
data_tub =  data.loc[data['disease_category'].apply(lambda x: x in ['diab/ tb ', 'tuberculosis '])].copy()
data_dia_aga = data_dia.loc[data_dia['author'].apply(lambda x: x in ['agathiyar'])]
data_dia_the = data_dia.loc[data_dia['author'].apply(lambda x: x in ['therayar'])]
data_tub_aga = data_tub.loc[data_tub['author'].apply(lambda x: x in ['agathiyar'])]
data_tub_the = data_tub.loc[data_tub['author'].apply(lambda x: x in ['therayar'])]

# %%
data_dia
# Out:
#                         drug     author                bot_name  \
# 0    parangipattai choornam   agathiyar            smilax china
# 1    parangipattai choornam   agathiyar    tinospora cordifolia
# 2           aavarai kiyalam   agathiyar       cassia auriculata
# 3           aavarai kiyalam   agathiyar              kalamadham
# 4           aavarai kiyalam   agathiyar          cassis fistula
# ..                       ...        ...                     ...
# 725        kodasalak kulikai   therayar        coccinia grandis
# 726        kodasalak kulikai   therayar    curculigo orchioides
# 727        kodasalak kulikai   therayar        cyperus rotundus
# 728        kodasalak kulikai   therayar  andrographis echioides
# 729        kodasalak kulikai   therayar                aridaram
#
#     disease_category
# 0           diabetes
# 1           diabetes
# 2           diabetes
# 3           diabetes
# 4           diabetes
# ..               ...
# 725         diabetes
# 726         diabetes
# 727         diabetes
# 728         diabetes
# 729         diabetes
#
# [481 rows x 4 columns]

# %%
def enc(data, name):
    def remove_duplicates(row):
        # numbers = row.split()
        unique_numbers = list(set(row))
        return unique_numbers
    # groupby drug and gather all bot_name with similar drug to an array
    grouped_data = data.groupby('drug')['bot_name'].apply(lambda x: x.tolist()).reset_index()
    # convert to series
    return pd.Series(grouped_data['bot_name']).apply(remove_duplicates).tolist()
    # return grouped_data

# %%
def apply_apriori(data, name:str, support:float=0.3, confidence:float=0.3):
    te = TransactionEncoder()
    da=enc(data, name)
    df = te.fit_transform(da, set_pandas=True)
    freq_items = apriori(df, min_support=support)
    if freq_items.empty:
        print(f'Frequent Itemsets for {name} is empty with support {support}')
    else:
        rules = association_rules(freq_items, metric="confidence", min_threshold=confidence)
    if rules.empty:
        print(f'Rules for {name} is empty with support {support} and confidence {confidence}')
        rules = pd.DataFrame(columns=['antecedents','consequents','antecedent','support','consequent','support','support','confidence',	'lift',	'kulc'])
    return rules

# %%
def apply_apriori(data, name:str, support:float=0.3, confidence:float=0.3):
    te = TransactionEncoder()
    da=enc(data, name)
    df = te.fit_transform(da, set_pandas=True)
    freq_items = apriori(df, min_support=support)
    if freq_items.empty:
        print(f'Frequent Itemsets for {name} is empty with support {support}')
    else:
        rules = association_rules(freq_items, metric="confidence", min_threshold=confidence)
    if rules.empty:
        print(f'Rules for {name} is empty with support {support} and confidence {confidence}')
        rules = pd.DataFrame(columns=['antecedents','consequents','antecedent','support','consequent','support','support','confidence',	'lift',	'kulc'])
    return rules

# %%
def apply_fpgrowth(data, name:str, support:float=0.3, confidence:float=0.3):
    te = TransactionEncoder()
    da=enc(data, name)
    df = te.fit_transform(da, set_pandas=True)
    freq_items = fpgrowth(df, min_support=support)
    if freq_items.empty:
        print(f'Frequent Itemsets for {name} is empty with support {support}')
    else:
        rules = association_rules(freq_items, metric="confidence", min_threshold=confidence)
    if rules.empty:
        print(f'Rules for {name} is empty with support {support} and confidence {confidence}')
        rules = pd.DataFrame(columns=['antecedents','consequents','antecedent','support','consequent','support','support','confidence',	'lift',	'kulc'])
    return rules

# %%
def apply_eclat(data, name:str, support:float=0.3, confidence:float=0.3):
    te = TransactionEncoder()
    da=enc(data, name)
    df = te.fit_transform(da, set_pandas=True)
    freq_items = eclat(df, min_support=support)
    if freq_items.empty:
        print(f'Frequent Itemsets for {name} is empty with support {support}')
    else:
        rules = association_rules(freq_items, metric="confidence", min_threshold=confidence)
    if rules.empty:
        print(f'Rules for {name} is empty with support {support} and confidence {confidence}')
        rules = pd.DataFrame(columns=['antecedents','consequents','antecedent','support','consequent','support','support','confidence',	'lift',	'kulc'])
    return rules

# %%
def apply_hmine(data, name:str, support:float=0.3, confidence:float=0.3):
    te = TransactionEncoder()
    da=enc(data, name)
    df = te.fit_transform(da, set_pandas=True)
    freq_items = hmine(df, min_support=support)
    if freq_items.empty:
        print(f'Frequent Itemsets for {name} is empty with support {support}')
    else:
        rules = association_rules(freq_items, metric="confidence", min_threshold=confidence)
    if rules.empty:
        print(f'Rules for {name} is empty with support {support} and confidence {confidence}')
        rules = pd.DataFrame(columns=['antecedents','consequents','antecedent','support','consequent','support','support','confidence',	'lift',	'kulc'])
    return rules

# %%
apply_hmine(data_dia, 'diabetes', support=0.1, confidence=0.3)
# Out:
#                          antecedents                       consequents  \
# 0                          (trikatu)                (costus speciosus)
# 1                 (costus speciosus)                         (trikatu)
# 2                         (triphala)                (costus speciosus)
# 3                 (costus speciosus)                        (triphala)
# 4             (elettaria cardamomum)             (syzygium aromaticum)
# 5              (syzygium aromaticum)            (elettaria cardamomum)
# 6                          (trikatu)             (syzygium aromaticum)
# 7              (syzygium aromaticum)                         (trikatu)
# 8                          (trikatu)            (terminalia bellirica)
# 9             (terminalia bellirica)                         (trikatu)
# 10                         (trikatu)  (triphala, terminalia bellirica)
# 11                        (triphala)   (trikatu, terminalia bellirica)
# 12            (terminalia bellirica)               (trikatu, triphala)
# 13               (trikatu, triphala)            (terminalia bellirica)
# 14   (trikatu, terminalia bellirica)                        (triphala)
# 15  (triphala, terminalia bellirica)                         (trikatu)
# 16                        (triphala)            (terminalia bellirica)
# 17            (terminalia bellirica)                        (triphala)
# 18                         (trikatu)                        (triphala)
# 19                        (triphala)                         (trikatu)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.310345            0.155172  0.103448    0.333333  2.148148
# 1             0.155172            0.310345  0.103448    0.666667  2.148148
# 2             0.241379            0.155172  0.103448    0.428571  2.761905
# 3             0.155172            0.241379  0.103448    0.666667  2.761905
# 4             0.103448            0.137931  0.103448    1.000000  7.250000
# 5             0.137931            0.103448  0.103448    0.750000  7.250000
# 6             0.310345            0.137931  0.103448    0.333333  2.416667
# 7             0.137931            0.310345  0.103448    0.750000  2.416667
# 8             0.310345            0.155172  0.137931    0.444444  2.864198
# 9             0.155172            0.310345  0.137931    0.888889  2.864198
# 10            0.310345            0.137931  0.120690    0.388889  2.819444
# 11            0.241379            0.137931  0.120690    0.500000  3.625000
# 12            0.155172            0.137931  0.120690    0.777778  5.638889
# 13            0.137931            0.155172  0.120690    0.875000  5.638889
# 14            0.137931            0.241379  0.120690    0.875000  3.625000
# 15            0.137931            0.310345  0.120690    0.875000  2.819444
# 16            0.241379            0.155172  0.137931    0.571429  3.682540
# 17            0.155172            0.241379  0.137931    0.888889  3.682540
# 18            0.310345            0.241379  0.137931    0.444444  1.841270
# 19            0.241379            0.310345  0.137931    0.571429  1.841270
#
#         kulc
# 0   0.500000
# 1   0.500000
# 2   0.547619
# 3   0.547619
# 4   0.875000
# 5   0.875000
# 6   0.541667
# 7   0.541667
# 8   0.666667
# 9   0.666667
# 10  0.631944
# 11  0.687500
# 12  0.826389
# 13  0.826389
# 14  0.687500
# 15  0.631944
# 16  0.730159
# 17  0.730159
# 18  0.507937
# 19  0.507937

# %%
apply_fpgrowth(data_dia, 'diabetes', support=0.1, confidence=0.3)
# Out:
#                          antecedents                       consequents  \
# 0                          (trikatu)                (costus speciosus)
# 1                 (costus speciosus)                         (trikatu)
# 2                         (triphala)                (costus speciosus)
# 3                 (costus speciosus)                        (triphala)
# 4                          (trikatu)             (syzygium aromaticum)
# 5              (syzygium aromaticum)                         (trikatu)
# 6                          (trikatu)                        (triphala)
# 7                         (triphala)                         (trikatu)
# 8                         (triphala)            (terminalia bellirica)
# 9             (terminalia bellirica)                        (triphala)
# 10                         (trikatu)            (terminalia bellirica)
# 11            (terminalia bellirica)                         (trikatu)
# 12                         (trikatu)  (triphala, terminalia bellirica)
# 13                        (triphala)   (trikatu, terminalia bellirica)
# 14            (terminalia bellirica)               (trikatu, triphala)
# 15               (trikatu, triphala)            (terminalia bellirica)
# 16   (trikatu, terminalia bellirica)                        (triphala)
# 17  (triphala, terminalia bellirica)                         (trikatu)
# 18            (elettaria cardamomum)             (syzygium aromaticum)
# 19             (syzygium aromaticum)            (elettaria cardamomum)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.310345            0.155172  0.103448    0.333333  2.148148
# 1             0.155172            0.310345  0.103448    0.666667  2.148148
# 2             0.241379            0.155172  0.103448    0.428571  2.761905
# 3             0.155172            0.241379  0.103448    0.666667  2.761905
# 4             0.310345            0.137931  0.103448    0.333333  2.416667
# 5             0.137931            0.310345  0.103448    0.750000  2.416667
# 6             0.310345            0.241379  0.137931    0.444444  1.841270
# 7             0.241379            0.310345  0.137931    0.571429  1.841270
# 8             0.241379            0.155172  0.137931    0.571429  3.682540
# 9             0.155172            0.241379  0.137931    0.888889  3.682540
# 10            0.310345            0.155172  0.137931    0.444444  2.864198
# 11            0.155172            0.310345  0.137931    0.888889  2.864198
# 12            0.310345            0.137931  0.120690    0.388889  2.819444
# 13            0.241379            0.137931  0.120690    0.500000  3.625000
# 14            0.155172            0.137931  0.120690    0.777778  5.638889
# 15            0.137931            0.155172  0.120690    0.875000  5.638889
# 16            0.137931            0.241379  0.120690    0.875000  3.625000
# 17            0.137931            0.310345  0.120690    0.875000  2.819444
# 18            0.103448            0.137931  0.103448    1.000000  7.250000
# 19            0.137931            0.103448  0.103448    0.750000  7.250000
#
#         kulc
# 0   0.500000
# 1   0.500000
# 2   0.547619
# 3   0.547619
# 4   0.541667
# 5   0.541667
# 6   0.507937
# 7   0.507937
# 8   0.730159
# 9   0.730159
# 10  0.666667
# 11  0.666667
# 12  0.631944
# 13  0.687500
# 14  0.826389
# 15  0.826389
# 16  0.687500
# 17  0.631944
# 18  0.875000
# 19  0.875000

# %%
all_data = {
    'Diabetic-Data-Overall': data_dia,
    'Diabetic-Data-Agathiyar': data_dia_aga,
    'Diabetic-Data-Therayar': data_dia_the,
    'Tuberculosis-Data-Overall': data_tub,
    'Tuberculosis-Data-Agathiyar': data_tub_aga,
    'Tuberculosis-Data-Therayar': data_tub_the
    }

for name, data in all_data.items():
    write_split_data(data, name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       1 all_data = {
#       2     'Diabetic-Data-Overall': data_dia,
#       3     'Diabetic-Data-Agathiyar': data_dia_aga,
#    (...)
#       7     'Tuberculosis-Data-Therayar': data_tub_the
#       8     }
#      10 for name, data in all_data.items():
# ---> 11     write_split_data(data, name)
#
# NameError: name 'write_split_data' is not defined

# %%
def runSPMF(algorithm:str, name:str, support:int = 15):
    # Create algorithm folder if not exists
    if not os.path.exists(f'./output-data/{algorithm}'):
        os.makedirs(f'./output-data/{algorithm}')
    # if file does not exist create an empty file ./output-data/{algorithm}/{name}.txt 
    if not os.path.exists(f'./output-data/{algorithm}/{name}.txt'):
        open(f'./output-data/{algorithm}/{name}.txt', 'w').close()
    # Run SPMF
    os.system( f"java -jar spmf.jar run {algorithm} ./split-data/{name}.txt ./output-data/{algorithm}/{name}.txt {support}%")
    # Read the result from the output txt file
    with open(f'./output-data/{algorithm}/{name}.txt', 'r') as f:
        # Read output in format => 52 53  #SUP: 
        result = f.read()
    # Split the result into lines
    result = result.split('\n')
    out_dic = {}
    for row in result:
        # Get the bot_name and support value
        if not row:
            continue
        values = row.split(' #SUP: ')
        out_dic[str(values[0])] = values[1]
    out_df = pd.DataFrame.from_dict(out_dic, orient='index').reset_index()
    # if out_df is empty create aan empty dataframe with columns ['bot_name', 'support']
    if out_df.empty:
        out_df = pd.DataFrame(columns=['bot_name', 'support'])

    # Out_dic to df
    out_df.columns = ['bot_name', 'support']
    # Rename columns
    
    def to_bot_name(row):
        ids = row.split()
        bot_names = []
        for id in ids:
            bot_names.append(bot_name.loc[bot_name['id'] == int(id), 'bot_name'].values[0])
        return bot_names
    
    # out_df['bot_name'] = out_df['bot_name'].apply(to_bot_name)
    
    return out_df

# %%
def create_association_rules(df: pd.DataFrame, name: str, min_threshold: float = 0.7):
    
    df = df.copy()

    # Convert the 'support' column to integers
    try:
        df['bot_name'] = df['bot_name'].str.split()
    # Convert the 'bot_name' lists to frozensets
    except Exception as e:
        print(df)
        print(name)
        print(min_threshold)
        raise e
    df['support'] = df['support'].astype(int)
    df['bot_name'] = df['bot_name'].apply(frozenset)
    df.rename(columns={'bot_name': 'itemsets'}, inplace=True)
    # Create association rules
    if df.empty:
        rules = pd.DataFrame(columns=['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'confidence', 'lift', 'leverage', 'conviction'])
    else:
        rules = association_rules(df, metric='confidence', min_threshold=min_threshold)
        
    # If still empty print it in red color
    if rules.empty:
        print('\033[91m' + f'No rules found for {name} with min_threshold {min_threshold}' + '\033[0m')
    # Display the generated association rules
    return rules

# %%
# A function that calls run spmf and then create_association_rules to get association runs
import time
def mean_performance(algorithm:str, name:str):
    support_list = [10, 15, 20]
    confidence_list = [0.4, 0.5, 0.6]
    score_dic = {}
    performance_score = 0
    for support in support_list:
        supports = runSPMF(algorithm, name, support=support)
        for confidence in confidence_list:
            count = len(create_association_rules(supports, name, min_threshold=confidence))
            score_dic[str(support)+'_'+str(confidence)] = [len(supports), count]
            performance_score += count
            time.sleep(1)
    return score_dic
    return numpy.mean(performance_score/25)

# %%
algorithms = [
        'Apriori', 
        'FPGrowth_itemsets', 
        'Apriori_TID', 
        'Relim', 
        'Eclat'
        ]
ss = []
for algorithm in algorithms:
    ss.append(mean_performance(algorithm, 'Diabetic-Data-Overall').values())
# Out:
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 136
#  The algorithm stopped at size 2
#  Frequent itemsets count : 16
#  Maximum memory usage : 7.8111724853515625 mb
#  Total time ~ 15 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 10
#  The algorithm stopped at size 2
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 19 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3
#  The algorithm stopped at size 2
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.813987731933594 mb
#  Frequent itemsets count : 24
#  Total time ~ 40 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 4
#  Total time ~ 17 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 2
#  Total time ~ 25 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 15 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.5539703369140625 mb
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 24
#  Total time ~: 85 ms
#  Max memory:13.028984069824219
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 4
#  Total time ~: 13 ms
#  Max memory:7.811271667480469
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 2
#  Total time ~: 23 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Total time ~ 38 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Total time ~ 10 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Total time ~ 6 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6

# %%
pd.DataFrame(ss, index =algorithms ).T
# Out:
#    Apriori FPGrowth_itemsets Apriori_TID     Relim     Eclat
# 0  [16, 0]          [24, 17]    [24, 17]  [24, 17]  [24, 17]
# 1  [16, 0]          [24, 14]    [24, 14]  [24, 14]  [24, 14]
# 2  [16, 0]          [24, 11]    [24, 11]  [24, 11]  [24, 11]
# 3   [4, 0]            [4, 0]      [4, 0]    [4, 0]    [4, 0]
# 4   [4, 0]            [4, 0]      [4, 0]    [4, 0]    [4, 0]
# 5   [4, 0]            [4, 0]      [4, 0]    [4, 0]    [4, 0]
# 6   [2, 0]            [2, 0]      [2, 0]    [2, 0]    [2, 0]
# 7   [2, 0]            [2, 0]      [2, 0]    [2, 0]    [2, 0]
# 8   [2, 0]            [2, 0]      [2, 0]    [2, 0]    [2, 0]

# %%
apttemp = mean_performance('Apriori_TID', 'Diabetic-Data-Overall')
# Out:
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.5539703369140625 mb
#  Total time ~ 31 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# No rules found for Diabetic-Data-Overall with min_threshold 0.6

# %%
for key, value in apttemp.items():
    key = key.split('_')
    #
    print(key, value)
# Out:
# ['10', '0.4'] [24, 17]
# ['10', '0.5'] [24, 14]
# ['10', '0.6'] [24, 11]
# ['15', '0.4'] [4, 0]
# ['15', '0.5'] [4, 0]
# ['15', '0.6'] [4, 0]
# ['20', '0.4'] [2, 0]
# ['20', '0.5'] [2, 0]
# ['20', '0.6'] [2, 0]

# %%
def get_algorithms_scores(name:str):
    algorithms = [
        'Apriori', 
        'FPGrowth_itemsets', 
        'Apriori_TID', 
        'Relim', 
        'Eclat'
        ]
    
    avg_scores = {}
    for algorithm in algorithms:
        avg_scores[algorithm] = mean_performance(algorithm, name=name)
    return avg_scores

# %%
# 'Diabetic-Data-Overall'
# 'Diabetic-Data-Agathiyar'
# 'Diabetic-Data-Therayar'
# 'Tuberculosis-Data-Overall'
# 'Tuberculosis-Data-Agathiyar'
# 'Tuberculosis-Data-Therayar'

# get_algorithms_scores('Diabetic-Data-Agathiyar')

# %%
data_scores = {}
for name, data in all_data.items():
    data_scores[name] = get_algorithms_scores(name=name)
# Out:
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 903
#  The algorithm stopped at size 2
#  Frequent itemsets count : 42
#  Maximum memory usage : 7.8136444091796875 mb
#  Total time ~ 34 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 903
#  The algorithm stopped at size 2
#  Frequent itemsets count : 42
#  Maximum memory usage : 7.8136444091796875 mb
#  Total time ~ 22 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 903
#  The algorithm stopped at size 2
#  Frequent itemsets count : 42
#  Maximum memory usage : 7.8136444091796875 mb
#  Total time ~ 22 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 903
#  The algorithm stopped at size 2
#  Frequent itemsets count : 42
#  Maximum memory usage : 7.8136444091796875 mb
#  Total time ~ 25 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 903
#  The algorithm stopped at size 2
#  Frequent itemsets count : 42
#  Maximum memory usage : 7.8136444091796875 mb
#  Total time ~ 24 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 136
#  The algorithm stopped at size 2
#  Frequent itemsets count : 16
#  Maximum memory usage : 7.8111724853515625 mb
#  Total time ~ 19 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 136
#  The algorithm stopped at size 2
#  Frequent itemsets count : 16
#  Maximum memory usage : 7.8111724853515625 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 136
#  The algorithm stopped at size 2
#  Frequent itemsets count : 16
#  Maximum memory usage : 7.8111724853515625 mb
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 136
#  The algorithm stopped at size 2
#  Frequent itemsets count : 16
#  Maximum memory usage : 7.8111724853515625 mb
#  Total time ~ 12 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 136
#  The algorithm stopped at size 2
#  Frequent itemsets count : 16
#  Maximum memory usage : 7.8111724853515625 mb
#  Total time ~ 13 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 10
#  The algorithm stopped at size 2
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 10
#  The algorithm stopped at size 2
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 10
#  The algorithm stopped at size 2
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 10
#  The algorithm stopped at size 2
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 10
#  The algorithm stopped at size 2
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3
#  The algorithm stopped at size 2
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3
#  The algorithm stopped at size 2
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3
#  The algorithm stopped at size 2
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3
#  The algorithm stopped at size 2
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3
#  The algorithm stopped at size 2
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.812141418457031 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 1
#  The algorithm stopped at size 2
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 1
#  The algorithm stopped at size 2
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 1
#  The algorithm stopped at size 2
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 1
#  The algorithm stopped at size 2
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 12 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 1
#  The algorithm stopped at size 2
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 4 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 8.028984069824219 mb
#  Frequent itemsets count : 278
#  Total time ~ 20 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 8.028984069824219 mb
#  Frequent itemsets count : 278
#  Total time ~ 30 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 8.028984069824219 mb
#  Frequent itemsets count : 278
#  Total time ~ 21 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 8.028984069824219 mb
#  Frequent itemsets count : 278
#  Total time ~ 38 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 8.028984069824219 mb
#  Frequent itemsets count : 278
#  Total time ~ 22 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 24
#  Total time ~ 11 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 24
#  Total time ~ 11 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 24
#  Total time ~ 15 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 24
#  Total time ~ 14 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 24
#  Total time ~ 17 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 4
#  Total time ~ 37 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 4
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 4
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 4
#  Total time ~ 10 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 4
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 2
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 2
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 2
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 2
#  Total time ~ 10 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 2
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 1
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 1
#  Total time ~ 10 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.813987731933594 mb
#  Frequent itemsets count : 1
#  Total time ~ 12 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 1
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 58
#  Max memory usage: 7.818885803222656 mb
#  Frequent itemsets count : 1
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 35 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 17 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 25 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 25 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 31 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 11 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 12 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 14 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 9 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 10 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 12 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 10 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 10 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 8 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI TID v2.12 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 12 ms
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 278
#  Total time ~: 814 ms
#  Max memory:92.01990509033203
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 278
#  Total time ~: 833 ms
#  Max memory:99.01453399658203
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 278
#  Total time ~: 780 ms
#  Max memory:92.01679229736328
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 278
#  Total time ~: 778 ms
#  Max memory:97.00614166259766
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 278
#  Total time ~: 696 ms
#  Max memory:98.0246353149414
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 24
#  Total time ~: 43 ms
#  Max memory:13.290962219238281
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 24
#  Total time ~: 69 ms
#  Max memory:13.290962219238281
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 24
#  Total time ~: 57 ms
#  Max memory:13.291030883789062
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 24
#  Total time ~: 52 ms
#  Max memory:13.290962219238281
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 24
#  Total time ~: 38 ms
#  Max memory:13.290962219238281
# =====================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 4
#  Total time ~: 13 ms
#  Max memory:7.811271667480469
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 4
#  Total time ~: 9 ms
#  Max memory:7.811271667480469
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 4
#  Total time ~: 8 ms
#  Max memory:7.811271667480469
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 4
#  Total time ~: 9 ms
#  Max memory:7.811271667480469
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 4
#  Total time ~: 11 ms
#  Max memory:7.811271667480469
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 2
#  Total time ~: 11 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 2
#  Total time ~: 12 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 2
#  Total time ~: 9 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 2
#  Total time ~: 37 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 2
#  Total time ~: 16 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 1
#  Total time ~: 10 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 1
#  Total time ~: 16 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 1
#  Total time ~: 11 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 1
#  Total time ~: 8 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# ========== RELIM - STATS ============
#  Number of frequent  itemsets: 1
#  Total time ~: 9 ms
#  Max memory:7.8112335205078125
# =====================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Total time ~ 12 ms
#  Maximum memory usage : 8.028984069824219 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Total time ~ 15 ms
#  Maximum memory usage : 8.028984069824219 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Total time ~ 14 ms
#  Maximum memory usage : 8.028984069824219 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Total time ~ 17 ms
#  Maximum memory usage : 8.028984069824219 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 278
#  Total time ~ 15 ms
#  Maximum memory usage : 8.028984069824219 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Total time ~ 6 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Total time ~ 5 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Total time ~ 6 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Total time ~ 6 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 24
#  Total time ~ 7 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Total time ~ 11 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Total time ~ 9 ms
#  Maximum memory usage : 7.8140106201171875 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Total time ~ 8 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Total time ~ 10 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 4
#  Total time ~ 6 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Total time ~ 13 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Total time ~ 4 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Total time ~ 4 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Total time ~ 9 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 2
#  Total time ~ 10 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Total time ~ 10 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Total time ~ 5 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Total time ~ 7 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Total time ~ 7 ms
#  Maximum memory usage : 7.8140106201171875 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 58
#  Frequent itemsets count : 1
#  Total time ~ 9 ms
#  Maximum memory usage : 7.826728820800781 mb
# ===================================================
# No rules found for Diabetic-Data-Overall with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 595
#  The algorithm stopped at size 3
#  Frequent itemsets count : 35
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 26 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 595
#  The algorithm stopped at size 3
#  Frequent itemsets count : 35
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 10 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 595
#  The algorithm stopped at size 3
#  Frequent itemsets count : 35
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 11 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 595
#  The algorithm stopped at size 3
#  Frequent itemsets count : 35
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 13 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 595
#  The algorithm stopped at size 3
#  Frequent itemsets count : 35
#  Maximum memory usage : 7.8110809326171875 mb
#  Total time ~ 26 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 66
#  The algorithm stopped at size 2
#  Frequent itemsets count : 11
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 9 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 66
#  The algorithm stopped at size 2
#  Frequent itemsets count : 11
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 16 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 66
#  The algorithm stopped at size 2
#  Frequent itemsets count : 11
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 30 ms
# ===================================================
# No rules found for Diabetic-Data-Agathiyar with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 66
#  The algorithm stopped at size 2
#  Frequent itemsets count : 11
#  Maximum memory usage : 7.551063537597656 mb
# ...
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 61
#  Total time ~ 14 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 61
#  Total time ~ 6 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 61
#  Total time ~ 6 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 18
#  Total time ~ 4 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 18
#  Total time ~ 4 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 18
#  Total time ~ 3 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 18
#  Total time ~ 13 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 18
#  Total time ~ 4 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 9
#  Total time ~ 4 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 9
#  Total time ~ 4 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 9
#  Total time ~ 3 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 9
#  Total time ~ 3 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 9
#  Total time ~ 5 ms
#  Maximum memory usage : 8.028984069824219 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 5
#  Total time ~ 5 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 5
#  Total time ~ 5 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 5
#  Total time ~ 5 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 5
#  Total time ~ 5 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  ECLAT v0.96r18 - STATS =============
#  Transactions count from database : 21
#  Frequent itemsets count : 5
#  Total time ~ 5 ms
#  Maximum memory usage : 7.813682556152344 mb
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3052
#  The algorithm stopped at size 6
#  Frequent itemsets count : 175
#  Maximum memory usage : 7.812469482421875 mb
#  Total time ~ 20 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3052
#  The algorithm stopped at size 6
#  Frequent itemsets count : 175
#  Maximum memory usage : 7.812469482421875 mb
#  Total time ~ 33 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3052
#  The algorithm stopped at size 6
#  Frequent itemsets count : 175
#  Maximum memory usage : 7.812469482421875 mb
#  Total time ~ 18 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3052
#  The algorithm stopped at size 6
#  Frequent itemsets count : 175
#  Maximum memory usage : 8.028984069824219 mb
#  Total time ~ 77 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 3052
#  The algorithm stopped at size 6
#  Frequent itemsets count : 175
#  Maximum memory usage : 7.812469482421875 mb
#  Total time ~ 27 ms
# ===================================================
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 4 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 19 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 3 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 16 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 253
#  The algorithm stopped at size 2
#  Frequent itemsets count : 22
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 55
#  The algorithm stopped at size 2
#  Frequent itemsets count : 10
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 7 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 55
#  The algorithm stopped at size 2
#  Frequent itemsets count : 10
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 3 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 55
#  The algorithm stopped at size 2
#  Frequent itemsets count : 10
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 55
#  The algorithm stopped at size 2
#  Frequent itemsets count : 10
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 4 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 55
#  The algorithm stopped at size 2
#  Frequent itemsets count : 10
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 6
#  The algorithm stopped at size 2
#  Frequent itemsets count : 3
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.4
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 6
#  The algorithm stopped at size 2
#  Frequent itemsets count : 3
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 4 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.5
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 6
#  The algorithm stopped at size 2
#  Frequent itemsets count : 3
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 3 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.6
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 6
#  The algorithm stopped at size 2
#  Frequent itemsets count : 3
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 6 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.7
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  APRIORI - STATS =============
#  Candidates count : 6
#  The algorithm stopped at size 2
#  Frequent itemsets count : 3
#  Maximum memory usage : 7.551063537597656 mb
#  Total time ~ 5 ms
# ===================================================
# No rules found for Tuberculosis-Data-Therayar with min_threshold 0.8
# >/media/harsh/Docs Volume/Documents/Data Science Community/herbal-analysis/spmf/spmf.jar
# =============  FP-GROWTH 2.42 - STATS =============
#  Transactions count from database : 13
#  Max memory usage: 41.02898406982422 mb
#  Frequent itemsets count : 4277305
#  Total time ~ 6110 ms
# ===================================================

# %%
data_scores
